# %%
# from functionimport import *

# awais("awais")

# def pow(a=2,b=1):
#     return a**b

# print(pow( 2))

# +++++++++++++=++++++positional and keyword +++++++++++++++

# def pow(a=2,b=1):
#     return a**b

# print(pow(b=2,a=3))


# ++++++++++++++++++++++Arbitary ++++++++++++++========+++

# def flexi(*numbs):
#     product = 1
#     print(type(numbs))
#     print(numbs)
#     for i in numbs:
#         product = product*i
#         print(product)
# flexi(5,4,5,6)



# def fun1():
#     return "func 1"


# def fun2(y):
#     print("func 2")
#     return y

# print(fun1())
# print(5+fun2(5))

# def f(y):
#     x = 1
#     x += 1
#     print(x)

# x = 6
# # f(x)
# print(x)


# def f(y):
#     print(x)
#     print(x+1)

# x = 6
# f(x)
# print(x)

# def f(y):
#     global x
#     x +=1
# x = 6
# f(x)
# print(x)

# def f():
#     print("inside f")
#     def g():
#         print("inside g")
#     g()
# f()

# x = "abx"
# x = x+1
# print(x)

# +++++++++++++++++++++everyrhing is object in py++++++++++++++++

def f(num):
    return num**4
print(f(4))
x = f
del f
# f(5)
print(x(4))

l = [1,2,3,4,x]
print(l[-1](4))
# Out:
# 256
# 256
# 256

# %%
def awais(z):
    '''
    this is function print anything you want
    '''
    if type(z) == int:
        if z%2==0:
            print("even")
        else:
            print("odd")
    else:
       print("not allowed")
